# %%
import pandas as pd
import numpy as np
url = r"../../taxpayer/data/Recursos_sep-22.xlsx"

df = pd.read_excel(url)

# %%
df.columns = ["code","description","value"]
df = df.dropna()
df["c1"] = df["code"] == 1
df["c2"] = df["code"].map(lambda x : len(str(x))==4)
df["c3"] = df["code"].map(lambda x : len(str(x))==7)
df["date"] = 0
df
# Out:
#               code                                        description  \
# 4                1                                Ingresos corrientes
# 5             1.01                          De jurisdicción municipal
# 6          1.01.01                               Ingresos Tributarios
# 7       1.01.01.01        Contribución que incide sobre los Inmuebles
# 8    1.01.01.01.01        Contribución que incide sobre los Inmuebles
# ..             ...                                                ...
# 199        4.01.02                               De origen provincial
# 200     4.01.02.01  Aportes del Fondo Provincial de Asistencia al ...
# 201        4.01.03                                De origen municipal
# 202           4.02  Transferencias de organismos que integran el P...
# 203           4.03                   Otras contribuciones figurativas
#
#                   value     c1     c2     c3  date
# 4    82082087756.299988   True  False  False     0
# ...
